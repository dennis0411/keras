# %%
import numpy as np
from keras import layers, models
from keras.datasets import imdb

MAX_WORDS = 15000
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=MAX_WORDS)
print(train_data[0])
print(max([max(sequence) for sequence in train_data]))

word_index = imdb.get_word_index()
print(type(word_index))
print(list(word_index.items())[:10])
reverse_word_index = dict([(v, k) for (k, v) in word_index.items()])
for i in range(5):
    decoded_review = ' '.join([reverse_word_index.get(i - 3, "?") for i in train_data[i]])
    print(decoded_review)


def vectorize_sequence(sequences, dimension=MAX_WORDS):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results


X_train = vectorize_sequence(train_data)
X_test = vectorize_sequence(test_data)
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')
print(X_train[0])
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)

model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(MAX_WORDS,)))
model.add(layers.Dense(1, activation='sigmoid'))
model.summary()
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=30, batch_size=256,
                    validation_data=(X_test, y_test))
# Out:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 10311, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 12118, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]
# 14999
# <class 'dict'>
# [('fawn', 34701), ('tsukino', 52006), ('nunnery', 52007), ('sonja', 16816), ('vani', 63951), ('woods', 1408), ('spiders', 16115), ('hanging', 2345), ('woody', 2289), ('trawling', 52008)]
# ? worst mistake of my life br br i picked this movie up at target for 5 because i figured hey it's sandler i can get some cheap laughs i was wrong completely wrong mid way through the film all three of my friends were asleep and i was still suffering worst plot worst script worst movie i have ever seen i wanted to hit my head up against a wall for an hour then i'd stop and you know why because it felt damn good upon bashing my head in i stuck that damn movie in the ? and watched it burn and that felt better than anything else i've ever done it took american psycho army of darkness and kill bill just to get over that crap i hate you sandler for actually going through with this and ruining a whole day of my life
# [0. 1. 1. ... 0. 0. 0.]
# (25000, 15000)
# (25000, 15000)
# (25000,)
# (25000,)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                960064
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 960,129
# Trainable params: 960,129
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 98/98 [==============================] - 5s 48ms/step - loss: 0.3581 - accuracy: 0.8505 - val_loss: 0.3246 - val_accuracy: 0.8658
# Epoch 2/30
# 98/98 [==============================] - 3s 34ms/step - loss: 0.2003 - accuracy: 0.9256 - val_loss: 0.2870 - val_accuracy: 0.8853
# Epoch 3/30
# 98/98 [==============================] - 3s 33ms/step - loss: 0.1492 - accuracy: 0.9466 - val_loss: 0.3529 - val_accuracy: 0.8663
# Epoch 4/30
# 98/98 [==============================] - 3s 32ms/step - loss: 0.1188 - accuracy: 0.9591 - val_loss: 0.3493 - val_accuracy: 0.8726
# Epoch 5/30
# 98/98 [==============================] - 3s 32ms/step - loss: 0.0973 - accuracy: 0.9656 - val_loss: 0.4272 - val_accuracy: 0.8595
# Epoch 6/30
# 98/98 [==============================] - 3s 32ms/step - loss: 0.0775 - accuracy: 0.9742 - val_loss: 0.4218 - val_accuracy: 0.8650
# Epoch 7/30
# 98/98 [==============================] - 3s 33ms/step - loss: 0.0631 - accuracy: 0.9787 - val_loss: 0.4689 - val_accuracy: 0.8622
# Epoch 8/30
# 98/98 [==============================] - 3s 33ms/step - loss: 0.0503 - accuracy: 0.9829 - val_loss: 0.5273 - val_accuracy: 0.8552
# Epoch 9/30
# 98/98 [==============================] - 3s 33ms/step - loss: 0.0398 - accuracy: 0.9879 - val_loss: 0.5733 - val_accuracy: 0.8542
# Epoch 10/30
# 98/98 [==============================] - 3s 34ms/step - loss: 0.0306 - accuracy: 0.9901 - val_loss: 0.6264 - val_accuracy: 0.8551
# Epoch 11/30
# 98/98 [==============================] - 3s 34ms/step - loss: 0.0231 - accuracy: 0.9924 - val_loss: 0.7666 - val_accuracy: 0.8441
# Epoch 12/30
# 98/98 [==============================] - 3s 34ms/step - loss: 0.0166 - accuracy: 0.9959 - val_loss: 0.7573 - val_accuracy: 0.8496
# Epoch 13/30
# 98/98 [==============================] - 3s 33ms/step - loss: 0.0130 - accuracy: 0.9967 - val_loss: 0.8439 - val_accuracy: 0.8454
# Epoch 14/30
# 98/98 [==============================] - 3s 33ms/step - loss: 0.0093 - accuracy: 0.9977 - val_loss: 0.8899 - val_accuracy: 0.8473
# Epoch 15/30
# 98/98 [==============================] - 3s 33ms/step - loss: 0.0063 - accuracy: 0.9986 - val_loss: 0.9682 - val_accuracy: 0.8447
# Epoch 16/30
# 98/98 [==============================] - 3s 34ms/step - loss: 0.0042 - accuracy: 0.9994 - val_loss: 1.0536 - val_accuracy: 0.8448
# Epoch 17/30
# 98/98 [==============================] - 3s 34ms/step - loss: 0.0031 - accuracy: 0.9996 - val_loss: 1.1050 - val_accuracy: 0.8456
# Epoch 18/30
# 98/98 [==============================] - 3s 34ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 1.2052 - val_accuracy: 0.8405
# Epoch 19/30
# 98/98 [==============================] - 3s 34ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.2652 - val_accuracy: 0.8434
# Epoch 20/30
# 98/98 [==============================] - 3s 34ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 1.3187 - val_accuracy: 0.8444
# Epoch 21/30
# 98/98 [==============================] - 3s 33ms/step - loss: 5.7812e-04 - accuracy: 1.0000 - val_loss: 1.3904 - val_accuracy: 0.8434
# Epoch 22/30
# 98/98 [==============================] - 3s 34ms/step - loss: 4.7110e-04 - accuracy: 0.9999 - val_loss: 1.4686 - val_accuracy: 0.8413
# Epoch 23/30
# 98/98 [==============================] - 3s 34ms/step - loss: 4.5935e-04 - accuracy: 0.9999 - val_loss: 1.5138 - val_accuracy: 0.8414
# Epoch 24/30
# 98/98 [==============================] - 3s 34ms/step - loss: 3.2776e-04 - accuracy: 1.0000 - val_loss: 1.5757 - val_accuracy: 0.8421
# Epoch 25/30
# 98/98 [==============================] - 3s 34ms/step - loss: 4.7214e-04 - accuracy: 0.9999 - val_loss: 1.6121 - val_accuracy: 0.8422
# Epoch 26/30
# 98/98 [==============================] - 3s 34ms/step - loss: 1.2018e-04 - accuracy: 1.0000 - val_loss: 1.6579 - val_accuracy: 0.8431
# Epoch 27/30
# 98/98 [==============================] - 3s 34ms/step - loss: 1.2773e-04 - accuracy: 1.0000 - val_loss: 1.7106 - val_accuracy: 0.8423
# Epoch 28/30
# 98/98 [==============================] - 3s 34ms/step - loss: 1.0045e-04 - accuracy: 1.0000 - val_loss: 1.7511 - val_accuracy: 0.8417
# Epoch 29/30
# 98/98 [==============================] - 3s 34ms/step - loss: 6.5683e-05 - accuracy: 1.0000 - val_loss: 1.8016 - val_accuracy: 0.8417
# Epoch 30/30
# 98/98 [==============================] - 3s 34ms/step - loss: 5.3292e-05 - accuracy: 1.0000 - val_loss: 1.8168 - val_accuracy: 0.8423

# %%
import matplotlib.pyplot as plt
history_dict = history.history
accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']
epochs = range(1, len(accuracy)+1)
plt.plot(epochs, accuracy, 'g--', label='accuracy')
plt.plot(epochs, val_accuracy, 'b-', label='validation accuracy')
plt.legend()

# %%
loss = history_dict['loss']
val_loss = history_dict['val_loss']
plt.plot(epochs, loss, 'g--', label='loss')
plt.plot(epochs, val_loss, 'b-', label='validation loss')
plt.legend()
